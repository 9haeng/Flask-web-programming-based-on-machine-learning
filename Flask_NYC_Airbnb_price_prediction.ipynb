# %% [markdown]
# # **Flask를 활용한 머신러닝 기반의 숙소 가격 예측 웹 페이지 만들기**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 지난 NYC Airbnb 숙소 가격 예측 [머신러닝 프로젝트](https://github.com/9haeng/NYC-Airbnb-price-prediction)를 활용하여 웹 페이지 구현

# %% [markdown]
# # **플라스크 가동**

# %% [markdown]
# ![플라스크 가동.gif](data:image/gif;base64,...)

# %% [markdown]
# # **홈페이지 구성**

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# **숙소 가격 예측을 위한 선택지**

# %% [markdown]
# ![선택지.png](data:image/png;base64,...)

# %% [markdown]
# # **숙소 가격 예측에 성공할 경우**

# %% [markdown]
# ![가격 예측 성공.gif](data:image/gif;base64,...)

# %% [markdown]
# ![result.png](data:image/png;base64,...)

# %% [markdown]
# # **가격 예측에 실패할 경우**
# (예측 값이 음수일 경우 에러 메시지 반환)

# %% [markdown]
# ![가격 예측 실패.gif](data:image/gif;base64,...)

# %% [markdown]
# ![result2.png](data:image/png;base64,...)
